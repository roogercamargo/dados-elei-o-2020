# %% [markdown]
# # Análise de Eleitorado 2020

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
low_memory = False
# %matplotlib inline

# %%
sns.set()

# %%
plt.rcParams['figure.figsize'] = (11,7)

# %%
filename=r'C:\Users\User\Desktop\Pandas\analise-de-dados\perfil_eleitorado_2020.csv'
df = pd.read_csv(filename, delimiter=';', 
                 encoding='ISO-8859-1',
                 error_bad_lines=False)

# %%
df.shape
# Out:
# (4248094, 21)

# %%
df.describe()
# Out:
#        ANO_ELEICAO  CD_MUNICIPIO  CD_MUN_SIT_BIOMETRIA       NR_ZONA  \
# count    4248094.0  4.248094e+06             4248094.0  4.248094e+06
# mean        2020.0  5.185142e+04                   0.0  9.924224e+01
# std            0.0  2.838188e+04                   0.0  9.135318e+01
# min         2020.0  1.900000e+01                   0.0  1.000000e+00
# 25%         2020.0  2.605000e+04                   0.0  3.100000e+01
# 50%         2020.0  5.502600e+04                   0.0  7.000000e+01
# 75%         2020.0  7.581700e+04                   0.0  1.400000e+02
# max         2020.0  9.907400e+04                   0.0  4.270000e+02
#
#           CD_GENERO  CD_ESTADO_CIVIL  CD_FAIXA_ETARIA  CD_GRAU_ESCOLARIDADE  \
# count  4.248094e+06     4.248094e+06     4.248094e+06          4.248094e+06
# mean   3.039351e+00     3.877925e+00     5.279233e+03          4.243415e+00
# std    1.019964e+00     2.837533e+00     2.105586e+03          2.219567e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4248094 entries, 0 to 4248093
# Data columns (total 21 columns):
#  #   Column                      Dtype
# ---  ------                      -----
#  0   DT_GERACAO                  object
#  1   HH_GERACAO                  object
#  2   ANO_ELEICAO                 int64
#  3   SG_UF                       object
#  4   CD_MUNICIPIO                int64
#  5   NM_MUNICIPIO                object
#  6   CD_MUN_SIT_BIOMETRIA        int64
#  7   DS_MUN_SIT_BIOMETRIA        object
#  8   NR_ZONA                     int64
#  9   CD_GENERO                   int64
#  10  DS_GENERO                   object
#  11  CD_ESTADO_CIVIL             int64
#  12  DS_ESTADO_CIVIL             object
#  13  CD_FAIXA_ETARIA             int64
#  14  DS_FAIXA_ETARIA             object
#  15  CD_GRAU_ESCOLARIDADE        int64
#  16  DS_GRAU_ESCOLARIDADE        object
#  17  QT_ELEITORES_PERFIL         int64
#  18  QT_ELEITORES_BIOMETRIA      int64
# ...

# %%
df.sample(5)
# Out:
#          DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 1503999  10/09/2020   23:04:11         2020    AM          2739
# 1401675  10/09/2020   23:04:11         2020    MG         54038
# 1418119  10/09/2020   23:04:11         2020    MT         91510
# 2234292  10/09/2020   23:04:11         2020    MA          8028
# 976581   10/09/2020   23:04:11         2020    SP         64777
#
#                     NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  \
# 1503999     SANTO ANTÔNIO DO IÇÁ                     0        Sem biometria
# 1401675               UBERLÂNDIA                     0        Sem biometria
# 1418119             RONDONÓPOLIS                     0        Sem biometria
# 2234292  OLINDA NOVA DO MARANHÃO                     0        Sem biometria
# 976581                 GUARULHOS                     0        Sem biometria
#
#          NR_ZONA  CD_GENERO  ... CD_ESTADO_CIVIL         DS_ESTADO_CIVIL  \
# ...

# %%
df.columns.values
# Out:
# array(['DT_GERACAO', 'HH_GERACAO', 'ANO_ELEICAO', 'SG_UF', 'CD_MUNICIPIO',
#        'NM_MUNICIPIO', 'CD_MUN_SIT_BIOMETRIA', 'DS_MUN_SIT_BIOMETRIA',
#        'NR_ZONA', 'CD_GENERO', 'DS_GENERO', 'CD_ESTADO_CIVIL',
#        'DS_ESTADO_CIVIL', 'CD_FAIXA_ETARIA', 'DS_FAIXA_ETARIA',
#        'CD_GRAU_ESCOLARIDADE', 'DS_GRAU_ESCOLARIDADE',
#        'QT_ELEITORES_PERFIL', 'QT_ELEITORES_BIOMETRIA',
#        'QT_ELEITORES_DEFICIENCIA', 'QT_ELEITORES_INC_NM_SOCIAL'],
#       dtype=object)

# %%
dfSelecionados = ['SG_UF',
       'NM_MUNICIPIO', 'NR_ZONA', 'DS_GENERO', 'CD_FAIXA_ETARIA', 'DS_FAIXA_ETARIA',
       'CD_GRAU_ESCOLARIDADE', 'DS_GRAU_ESCOLARIDADE',
       'QT_ELEITORES_PERFIL']

# %%
dadosSelecionados = df.filter(items=dfSelecionados)

# %%
dadosSelecionados.head()
# Out:
#   SG_UF NM_MUNICIPIO  NR_ZONA DS_GENERO  CD_FAIXA_ETARIA  \
# 0    SP    SÃO PAULO      257  FEMININO             9094
# 1    SP    SÃO PAULO      257  FEMININO             9094
# 2    SP    SÃO PAULO      257  FEMININO             9094
# 3    SP    SÃO PAULO      257  FEMININO             9599
# 4    SP    SÃO PAULO      257  FEMININO             9599
#
#                   DS_FAIXA_ETARIA  CD_GRAU_ESCOLARIDADE  \
# 0  90 a 94 anos                                       6
# 1  90 a 94 anos                                       7
# 2  90 a 94 anos                                       8
# 3  95 a 99 anos                                       1
# 4  95 a 99 anos                                       2
#
#     DS_GRAU_ESCOLARIDADE  QT_ELEITORES_PERFIL
# 0  ENSINO MÉDIO COMPLETO                   17
# 1    SUPERIOR INCOMPLETO                    1
# 2      SUPERIOR COMPLETO                    8
# 3             ANALFABETO                   28
# 4           LÊ E ESCREVE                  149

# %%
escolaridade = dadosSelecionados['DS_GRAU_ESCOLARIDADE']

# %%
dadosSelecionados['DS_FAIXA_ETARIA'].value_counts().plot.bar()(kind='bar', title='idade dos eleitores 2020');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-eac439fc7f7f> in <module>
# ----> 1 dadosSelecionados['DS_FAIXA_ETARIA'].value_counts().plot.bar()(kind='bar', title='idade dos eleitores 2020');
#
# TypeError: 'AxesSubplot' object is not callable

# %%
dadosSelecionados.groupby('DS_GRAU_ESCOLARIDADE').size().sort_values().plot(kind='barh', title= 'Grau de escolaridade eleitor 2020');

# %%
idade = dadosSelecionados['DS_FAIXA_ETARIA']

# %%
idade.value_counts()
# Out:
# 55 a 59 anos                      357283
# 60 a 64 anos                      348873
# 50 a 54 anos                      346290
# 65 a 69 anos                      325249
# 45 a 49 anos                      324654
# 40 a 44 anos                      306811
# 70 a 74 anos                      288170
# 35 a 39 anos                      278457
# 75 a 79 anos                      241159
# 30 a 34 anos                      239901
# 25 a 29 anos                      199714
# 80 a 84 anos                      198060
# 85 a 89 anos                      147697
# 21 a 24 anos                      147427
# 90 a 94 anos                      106777
# 20 anos                            81676
# 19 anos                            73444
# 95 a 99 anos                       68564
# 18 anos                            61512
# 17 anos                            45748
# 16 anos                            30073
# 100 anos ou mais                   28455
# Inválido                            2100
# ...

# %%
estado = dadosSelecionados['SG_UF']

# %%
estado.value_counts()
# Out:
# SP    639502
# MG    609026
# RS    320563
# BA    317883
# PR    287673
# SC    198579
# RJ    197273
# GO    171810
# CE    160160
# PE    159852
# MA    141477
# PB    140778
# PI    128306
# PA    120859
# RN    105078
# MT     93213
# TO     73793
# AL     69281
# ES     68774
# MS     66692
# SE     50469
# AM     50225
# RO     39554
# AC     15844
# AP     10942
# RR     10488
# Name: SG_UF, dtype: int64

# %%
escolaridade_por_municipio = dadosSelecionados.groupby(['SG_UF', 'DS_GRAU_ESCOLARIDADE']).mean()

# %%
escolaridade_por_municipio
# Out:
#                                        NR_ZONA  CD_FAIXA_ETARIA  \
# SG_UF DS_GRAU_ESCOLARIDADE
# AC    ANALFABETO                      4.881441      5990.362798
#       ENSINO FUNDAMENTAL COMPLETO     4.951018      4689.023115
#       ENSINO FUNDAMENTAL INCOMPLETO   4.921031      4980.050363
#       ENSINO MÉDIO COMPLETO           4.905140      4664.035514
#       ENSINO MÉDIO INCOMPLETO         4.933373      4108.681014
# ...                                        ...              ...
# TO    ENSINO MÉDIO COMPLETO          17.148206      4497.958580
#       ENSINO MÉDIO INCOMPLETO        17.049687      3833.437672
#       LÊ E ESCREVE                   17.438422      6102.755497
#       SUPERIOR COMPLETO              17.017436      4731.309597
#       SUPERIOR INCOMPLETO            16.925213      3786.821067
#
#                                      CD_GRAU_ESCOLARIDADE  QT_ELEITORES_PERFIL
# SG_UF DS_GRAU_ESCOLARIDADE
# ...

# %%
dadosSelecionados.query('DS_GRAU_ESCOLARIDADE == "ANALFABETO"')['SG_UF'].value_counts().head().plot(kind='barh');

# %%
dadosSelecionados.query('SG_UF=="SP"')['DS_GRAU_ESCOLARIDADE'].value_counts().head().plot(kind='barh', title='grau de escolaridade eleitorado 2020');
